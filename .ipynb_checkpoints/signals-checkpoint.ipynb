# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
data_sin = pd.read_csv('sin_signal_sampled.csv')
plt.figure()
plt.plot(data_sin.iloc[:, 1])
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_sin_complex = pd.read_csv('sin_signal_complex.csv')
plt.figure()
plt.plot(data_sin_complex)
plt.xlabel('freq')
plt.ylabel('A')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_triangle = pd.read_csv("triangle_signal_sampled.csv")
plt.figure()
plt.plot(data_triangle.iloc[:, 1])
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_triangle = pd.read_csv("triangle_signal_complex.csv")
plt.figure()
plt.plot(data_triangle)
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_square = pd.read_csv("square_signal_sampled.csv")
plt.figure()
plt.plot(data_square.iloc[:, 1])
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_square_complex = pd.read_csv("square_signal_complex.csv")
plt.figure()
plt.plot(data_square_complex)
plt.xlabel('Samples')
plt.ylabel('A')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_dsquare = pd.read_csv("double_square_signal_sampled.csv")
plt.figure()
plt.plot(data_dsquare.iloc[:, 1])
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
data_dsquare_complex = pd.read_csv("double_square_signal_complex.csv")
plt.figure()
plt.plot(data_dsquare)
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.show()
